# %% [markdown]
# # Create Embedding Model for RAG [Triwira Data]
#
#   > **Note:** Due to limitations of GPU resources, this notebook uses `Google Colab T4 GPU` to fine-tune the embedding model.
#
# In this notebook we're going to make the embedding model. This model is plays significant role to produce context given a query. The context produced is inserted in ChatBot prompt RAG system.

# %% [markdown]
# ## 0. Get setup
# Let's start by downloading all of the modules we'll need for fine-tune the embedding model.

# %% [markdown]
# Downloading modules

# %%
# %%capture
# !pip install transformers[torch]
# !pip install -U sentence-transformers
# !pip install datasets

# %% [markdown]
# Importing modules

# %%
# Typing modules
from typing import List, Tuple, Dict, Optional

# Model builder and fine-tune
from sentence_transformers import SentenceTransformer
from sentence_transformers import SentenceTransformerTrainer, SentenceTransformerTrainingArguments
from sentence_transformers.losses import MultipleNegativesRankingLoss
from sentence_transformers.training_args import BatchSamplers

# Model evaluation
from sentence_transformers.evaluation import TripletEvaluator

# Dataset loader
import requests
from datasets import load_dataset
from datasets.arrow_dataset import Dataset
# Out:
# /usr/local/lib/python3.10/dist-packages/sentence_transformers/cross_encoder/CrossEncoder.py:11: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm, trange

# %% [markdown]
# ## 1. Build Embedding Model
# Set base embedding model from HuggingFace.

# %%
model = SentenceTransformer("BAAI/bge-m3")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/123 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/15.8k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/54.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/687 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/2.27G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/444 [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.1M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/964 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/191 [00:00<?, ?B/s]

# %% [markdown]
# ## 2. Get Data
# Because the RAG system use Indonesian language, we're going to fine-tune embedding model with Indonesian language triplet dataset.

# %%
def create_dataset(dataset_path: str,
                  test_size: float = 0.1,
                  source: str = "csv") -> Tuple[Dataset, Dataset]:
    """
    Prepares the dataset by loading and splitting it into training and testing sets.

    Args:
        dataset_path (str): The path to the dataset file.
        test_size (float, optional): The proportion of the dataset to include in the test split. Default is 0.1.
        source (str, optional): The source format of the dataset ("csv" or other supported formats). Default is "csv".

    Returns:
        tuple: A tuple containing the training dataset and the testing dataset.

    Example usage:
        train_dataset, test_dataset = create_dataset("data/dataset.csv", test_size=0.2)
    """

    if source == "csv":
        dataset = load_dataset(source, data_files=dataset_path, split="train")
        dataset = dataset.remove_columns(["anchor", "positive", "negative"])
        dataset = dataset.rename_column("Translated_anchor", "anchor")
        dataset = dataset.rename_column("Translated_positive", "positive")
        dataset = dataset.rename_column("Translated_negative", "negative")
    else:
        dataset = load_dataset(dataset_path, split="train")

    dataset = dataset.train_test_split(test_size=0.1)
    used_dataset = dataset["test"]

    used_dataset = used_dataset.train_test_split(test_size=test_size)
    train_dataset = dataset["train"]
    test_dataset = dataset["test"]

    return train_dataset, test_dataset

# %%
try:
    # Create train test dataset if exist
    train_dataset, test_dataset = create_dataset("/content/translated_new_data_50000.csv")
    print(f"[INFO] train test dataset successfully created")
except:
    # Download dataset
    print(f"[INFO] Did not find datasets, downloading...")
    with open("translated_new_data_50000.csv", "wb") as f:
        request = requests.get("https://raw.githubusercontent.com/MarcoAlandAdinanda/AIC_TriwiraData/main/data/translated_new_data_50000.csv")
        f.write(request.content)

    # Create train test dataset
    train_dataset, test_dataset = create_dataset("/content/translated_new_data_50000.csv")
    print(f"[INFO] train test dataset successfully created")
# Out:
# [INFO] Did not find datasets, downloading...
# Generating train split: 0 examples [00:00, ? examples/s]
# [INFO] train test dataset successfully created

# %% [markdown]
# ## 3. Fine-tuning the Embedding model
# We're going to make fine-tuning function to make the process more structured.

# %%
def train_embedding_model(model: SentenceTransformer,
                          train_dataset: Dataset,
                          test_dataset: Dataset,
                          outdir: str = "model",
                          batch_size: int = 4,
                          epochs: int = 1,
                          eval_steps: int = 100,
                          logging_steps: int = 100) -> SentenceTransformerTrainer:
    """
    Train an embedding model using the provided training and testing datasets.

    Args:
        model (SentenceTransformer): The model to be trained.
        train_dataset (Dataset): The training dataset.
        test_dataset (Dataset): The testing dataset.
        outdir (str, optional): The output directory where the model checkpoints will be saved. Default is "model".
        batch_size (int, optional): The batch size to use during training. Default is 4.
        epochs (int, optional): The number of epochs to train the model. Default is 3.
        eval_steps (int, optional): The number of steps between evaluations. Default is 100.
        logging_steps (int, optional): The number of steps between logging. Default is 100.

    Returns:
        SentenceTransformerTrainer: The trainer instance configured with the specified training arguments.

    Example usage:
        trainer = train_embedding_model(model, train_dataset, test_dataset, outdir="model_output", batch_size=8, epochs=5)
    """

    loss = MultipleNegativesRankingLoss(model)

    args = SentenceTransformerTrainingArguments(
        output_dir=outdir,
        num_train_epochs=epochs,
        per_device_train_batch_size=batch_size,
        per_device_eval_batch_size=batch_size,
        warmup_ratio=0.1,
        batch_sampler=BatchSamplers.NO_DUPLICATES,
        eval_strategy="steps",
        eval_steps=eval_steps,
        logging_steps=logging_steps,
    )

    trainer = SentenceTransformerTrainer(
        model=model,
        args=args,
        train_dataset=train_dataset,
        eval_dataset=test_dataset,
        loss=loss
    )

    return trainer

# %%
trainer = train_embedding_model(model, train_dataset, test_dataset)
train_stats = trainer.train()
# Out:
#     <div>
#
#       <progress value='501' max='11250' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [  501/11250 10:48 < 3:52:41, 0.77 it/s, Epoch 0.04/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>100</td>
#       <td>0.810000</td>
#       <td>0.552806</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>0.539700</td>
#       <td>0.494758</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>0.534900</td>
#       <td>0.514671</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>0.534200</td>
#       <td>0.547470</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>0.443300</td>
#       <td>0.567851</td>
#     </tr>
#   </tbody>
# </table><p>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-0185284808d9> in <cell line: 2>()
#       1 trainer = train_embedding_model(model, train_dataset, test_dataset)
# ----> 2 train_stats = trainer.train()
#
# /usr/local/lib/python3.10/dist-packages/transformers/trainer.py in train(self, resume_from_checkpoint, trial, ignore_keys_for_eval, **kwargs)
#    1930                 hf_hub_utils.enable_progress_bars()
#    1931         else:
# -> 1932             return inner_training_loop(
#    1933                 args=args,
#    1934                 resume_from_checkpoint=resume_from_checkpoint,
#
# /usr/local/lib/python3.10/dist-packages/transformers/trainer.py in _inner_training_loop(self, batch_size, args, resume_from_checkpoint, trial, ignore_keys_for_eval)
#    2343                     self.control = self.callback_handler.on_step_end(args, self.state, self.control)
#    2344
# -> 2345                     self._maybe_log_save_evaluate(tr_loss, grad_norm, model, trial, epoch, ignore_keys_for_eval)
#    2346                 else:
#    2347                     self.control = self.callback_handler.on_substep_end(args, self.state, self.control)
#
# /usr/local/lib/python3.10/dist-packages/transformers/trainer.py in _maybe_log_save_evaluate(self, tr_loss, grad_norm, model, trial, epoch, ignore_keys_for_eval)
#    2794
#    2795         if self.control.should_save:
# -> 2796             self._save_checkpoint(model, trial, metrics=metrics)
#    2797             self.control = self.callback_handler.on_save(self.args, self.state, self.control)
#    2798
#
# /usr/local/lib/python3.10/dist-packages/transformers/trainer.py in _save_checkpoint(self, model, trial, metrics)
#    2873         run_dir = self._get_output_dir(trial=trial)
#    2874         output_dir = os.path.join(run_dir, checkpoint_folder)
# -> 2875         self.save_model(output_dir, _internal_call=True)
#    2876
#    2877         if not self.args.save_only_model:
#
# /usr/local/lib/python3.10/dist-packages/transformers/trainer.py in save_model(self, output_dir, _internal_call)
#    3427
#    3428         elif self.args.should_save:
# -> 3429             self._save(output_dir)
#    3430
#    3431         # Push to the Hub when `save_model` is called by the user.
#
# /usr/local/lib/python3.10/dist-packages/sentence_transformers/trainer.py in _save(self, output_dir, state_dict)
#     725         logger.info(f"Saving model checkpoint to {output_dir}")
#     726
# --> 727         self.model.save_pretrained(output_dir, safe_serialization=self.args.save_safetensors)
#     728
#     729         if self.tokenizer is not None:
#
# /usr/local/lib/python3.10/dist-packages/sentence_transformers/SentenceTransformer.py in save_pretrained(self, path, model_name, create_model_card, train_datasets, safe_serialization)
#    1070                 the traditional (but unsafe) PyTorch way.
#    1071         """
# -> 1072         self.save(
#    1073             path,
#    1074             model_name=model_name,
#
# /usr/local/lib/python3.10/dist-packages/sentence_transformers/SentenceTransformer.py in save(self, path, model_name, create_model_card, train_datasets, safe_serialization)
#    1035             # Try to save with safetensors, but fall back to the traditional PyTorch way if the module doesn't support it
#    1036             try:
# -> 1037                 module.save(model_path, safe_serialization=safe_serialization)
#    1038             except TypeError:
#    1039                 module.save(model_path)
#
# /usr/local/lib/python3.10/dist-packages/sentence_transformers/models/Transformer.py in save(self, output_path, safe_serialization)
#     178
#     179     def save(self, output_path: str, safe_serialization: bool = True) -> None:
# --> 180         self.auto_model.save_pretrained(output_path, safe_serialization=safe_serialization)
#     181         self.tokenizer.save_pretrained(output_path)
#     182
#
# /usr/local/lib/python3.10/dist-packages/transformers/modeling_utils.py in save_pretrained(self, save_directory, is_main_process, state_dict, save_function, push_to_hub, max_shard_size, safe_serialization, variant, token, save_peft_format, **kwargs)
#    2682                 # At some point we will need to deal better with save_function (used for TPU and other distributed
#    2683                 # joyfulness), but for now this enough.
# -> 2684                 safe_save_file(shard, os.path.join(save_directory, shard_file), metadata={"format": "pt"})
#    2685             else:
#    2686                 save_function(shard, os.path.join(save_directory, shard_file))
#
# /usr/local/lib/python3.10/dist-packages/safetensors/torch.py in save_file(tensors, filename, metadata)
#     282     ```
#     283     """
# --> 284     serialize_file(_flatten(tensors), filename, metadata=metadata)
#     285
#     286
#
# /usr/local/lib/python3.10/dist-packages/safetensors/torch.py in _flatten(tensors)
#     486         )
#     487
# --> 488     return {
#     489         k: {
#     490             "dtype": str(v.dtype).split(".")[-1],
#
# /usr/local/lib/python3.10/dist-packages/safetensors/torch.py in <dictcomp>(.0)
#     490             "dtype": str(v.dtype).split(".")[-1],
#     491             "shape": v.shape,
# --> 492             "data": _tobytes(v, k),
#     493         }
#     494         for k, v in tensors.items()
#
# /usr/local/lib/python3.10/dist-packages/safetensors/torch.py in _tobytes(tensor, name)
#     412     if tensor.device.type != "cpu":
#     413         # Moving tensor to cpu before saving
# --> 414         tensor = tensor.to("cpu")
#     415
#     416     import ctypes
#
# KeyboardInterrupt:

# %% [markdown]
# ## 4. Evaluate fine-tuned model
# The evaluation method used is TripletEvaluator by SentenceTransformer. If the model giving the response as expected then we're good to go.

# %%
def evaluate_model(model: SentenceTransformer,
                   test_dataset: Dataset,
                   name: str = "model-evaluation"):
    """
    Evaluate the model using the provided test dataset.

    Args:
        model (SentenceTransformer): The model to be evaluated.
        test_dataset (Dataset): The testing dataset containing "anchor", "positive", and "negative" columns.
        name (str, optional): The name for the evaluation. Default is "test_model".

    Returns:
        dict: Evaluation results.

    Example usage:
        results = evaluate_model(model, test_dataset, name="evaluation")
    """

    test_evaluator = TripletEvaluator(
        anchors=test_dataset["anchor"],
        positives=test_dataset["positive"],
        negatives=test_dataset["negative"],
        name=name,
    )

    return test_evaluator(model)

# %%
# Start evaluate the model
eval_stats = evaluate_model(model, test_dataset)
eval_stats
# Out:
# {'model-evaluation_cosine_accuracy': 0.9596,
#  'model-evaluation_dot_accuracy': 0.0404,
#  'model-evaluation_manhattan_accuracy': 0.9592,
#  'model-evaluation_euclidean_accuracy': 0.9596,
#  'model-evaluation_max_accuracy': 0.9596}

# %% [markdown]
# ## 5. Save Model in HuggingFace
# In order to easily call the embedding model, we're going to push our model to HuggingFace.

# %%
from huggingface_hub import notebook_login

notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
model.push_to_hub("Indonesian-bge-m3")
# Out:
# Computing widget examples:   0%|          | 0/1 [00:00<?, ?example/s]
# sentencepiece.bpe.model:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# Upload 3 LFS files:   0%|          | 0/3 [00:00<?, ?it/s]
# model.safetensors:   0%|          | 0.00/2.27G [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.1M [00:00<?, ?B/s]
# 'https://huggingface.co/MarcoAland/Indonesian-bge-m3/commit/0c1c64af5c5ed01723f1ad17152e7ff813f39ba1'
